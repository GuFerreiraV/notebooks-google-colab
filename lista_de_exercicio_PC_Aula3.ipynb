# %% [markdown]
# <a href="https://colab.research.google.com/github/GuFerreiraV/notebooks-google-colab/blob/main/lista_de_exercicio_PC_Aula3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Questão 1: Volume do tronco de uma pirâmide
#
# Faça um programa em Python que calcule e mostre o valor do volume do tronco de uma pirâmide, para isso o programa deve solicitar ao usuário os valores da altura do tronco da pirâmide (h), o valor da base menor (Bmenor) e o da base maior (Bmaior) e calcular a seguinte expressão:
#
# volume = h/3*(Bmaior**2 + Bmenor**2 + (Bmaior**2 * Bmenor**2)**0.5)

# %%
# Solicita os valores ao usuário
h = float(input("Digite a altura do tronco da pirâmide (h): "))
Bmaior = float(input("Digite o valor da base maior (Bmaior): "))
Bmenor = float(input("Digite o valor da base menor (Bmenor): "))

# Calcula o volume do tronco da pirâmide
volume = (h / 3) * (Bmaior**2 + Bmenor**2 + (Bmaior**2 * Bmenor**2)**0.5)

# Mostra o resultado
print(f"O volume do tronco da pirâmide é: {volume:.2f}")
# Out:
# Digite a altura do tronco da pirâmide (h): 10
# Digite o valor da base maior (Bmaior): 2
# Digite o valor da base menor (Bmenor): 1
# O volume do tronco da pirâmide é: 23.33

# %% [markdown]
# ### Questão 2: Converter horas para minutos
#
# Crie um programa em Python que solicite o valor em horas para o usuário, calcule e mostre o valor em minutos, sabendo que 1 hora tem 60 minutos.

# %%
# Solicita o valor em horas ao usuário
horas = float(input("Digite o valor em horas: "))

# Calcula o valor em minutos
minutos = horas * 60

# Mostra o resultado
print(f"{horas} horas equivalem a {minutos:.2f} minutos.")
# Out:
# Digite o valor em horas: 20
# 20.0 horas equivalem a 1200.00 minutos.

# %% [markdown]
# ### Questão 3: Idade expressa em dias
#
# Crie um programa em Python que solicite ao usuário a sua idade expressa em anos, meses e dias (variáveis separadas). Calcule e mostre a idade expressa apenas em dias. Para isso considere 1 ano = 365 dias, 1 mês = 30 dias.

# %%
# Solicita a idade em anos, meses e dias
anos = int(input("Digite sua idade em anos: "))
meses = int(input("Digite sua idade em meses: "))
dias = int(input("Digite sua idade em dias: "))

# Calcula a idade total em dias
idade_em_dias = (anos * 365) + (meses * 30) + dias

# Mostra o resultado
print(f"Sua idade total em dias é: {idade_em_dias} dias.")
# Out:
# Digite sua idade em anos: 30
# Digite sua idade em meses: 20
# Digite sua idade em dias: 20
# Sua idade total em dias é: 11570 dias.

# %% [markdown]
# ### Questão 4: Valor de prestação em atraso
#
# Escreva um programa em Python para calcular o valor de uma prestação em atraso (prestacao). Para isso, obtenha o valor da prestação (valorPrestacao), a porcentagem de multa pelo atraso (multa) e a quantidade de dias de atraso (qtdeDias). Calcular e mostrar o valor da prestação atualizado, sabendo que:
#
# prestacao = valorPrestacao + (valorPrestacao * (multa / 100) * qtdeDias)

# %%
# Solicita os valores ao usuário
valorPrestacao = float(input("Digite o valor da prestação: "))
multa = float(input("Digite a porcentagem de multa pelo atraso (%): "))
qtdeDias = int(input("Digite a quantidade de dias de atraso: "))

# Calcula o valor da prestação atualizado
prestacao = valorPrestacao + (valorPrestacao * (multa / 100) * qtdeDias)

# Mostra o resultado
print(f"O valor da prestação atualizado é: R$ {prestacao:.2f}")
# Out:
# Digite o valor da prestação: 20
# Digite a porcentagem de multa pelo atraso (%): 20
# Digite a quantidade de dias de atraso: 20
# O valor da prestação atualizado é: R$ 100.00

# %% [markdown]
# ### Questão 5: Seno, Cosseno e Tangente de um ângulo
#
# Faça uma programa em Python que peça do usuário um valor em graus para um ângulo. Converta-o para radianos e, usando funções da biblioteca `math`, imprima o seno, cosseno e tangente deste ângulo.

# %%
import math

# Solicita o valor do ângulo em graus ao usuário
angulo_graus = float(input("Digite o valor do ângulo em graus: "))

# Converte o ângulo para radianos
angulo_radianos = math.radians(angulo_graus)

# Calcula o seno, cosseno e tangente
seno = math.sin(angulo_radianos)
cosseno = math.cos(angulo_radianos)
tangente = math.tan(angulo_radianos)

# Imprime os resultados
print(f"Ângulo em graus: {angulo_graus}")
print(f"Ângulo em radianos: {angulo_radianos:.4f}")
print(f"Seno: {seno:.4f}")
print(f"Cosseno: {cosseno:.4f}")
print(f"Tangente: {tangente:.4f}")
# Out:
# Digite o valor do ângulo em graus: 20
# Ângulo em graus: 20.0
# Ângulo em radianos: 0.3491
# Seno: 0.3420
# Cosseno: 0.9397
# Tangente: 0.3640
